# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gold_price = pd.read_excel('data/Gold_Prices.xlsx')

# %%
gold_price_clean =  gold_price.dropna()

# %%
gold_price_clean
# Out:
#             Name  US dollar     Euro  Japanese yen  Pound sterling  \
# 3661  1993-01-11     328.40   264.61      41063.25          211.39
# 3662  1993-01-12     329.20   266.05      41256.88          213.77
# 3663  1993-01-13     327.55   265.16      41276.21          212.76
# 3664  1993-01-14     327.65   263.36      41182.70          213.11
# 3665  1993-01-15     327.70   265.06      41337.32          214.18
# ...          ...        ...      ...           ...             ...
# 10896 2020-10-05    1909.60  1619.33     201739.71         1471.41
# 10897 2020-10-06    1913.40  1622.69     202083.74         1475.02
# 10898 2020-10-07    1884.50  1602.26     199804.10         1460.97
# 10899 2020-10-08    1887.45  1606.54     200116.87         1459.86
# 10900 2020-10-09    1923.25  1627.87     203200.98         1479.65
#
#        Canadian dollar  Swiss franc  Indian rupee  Chinese renmimbi  \
# 3661            419.30       489.38       9447.19           1864.20
# ...

# %%
gold_price_clean.head()
# Out:
#            Name  US dollar    Euro  Japanese yen  Pound sterling  \
# 3661 1993-01-11     328.40  264.61      41063.25          211.39
# 3662 1993-01-12     329.20  266.05      41256.88          213.77
# 3663 1993-01-13     327.55  265.16      41276.21          212.76
# 3664 1993-01-14     327.65  263.36      41182.70          213.11
# 3665 1993-01-15     327.70  265.06      41337.32          214.18
#
#       Canadian dollar  Swiss franc  Indian rupee  Chinese renmimbi  \
# 3661           419.30       489.38       9447.19           1864.20
# 3662           420.16       493.27       9526.49           1885.12
# 3663           420.42       488.83       9478.63           1876.28
# 3664           418.65       485.35       9477.88           1879.30
# 3665           419.80       490.48       9507.58           1888.79
#
#       US dollar.1  ...  Vietnamese dong  Egyptian pound  Korean won  Euro.1  \
# 3661       328.40  ...       3501319.64         1072.23   258497.61  264.61
# ...

# %%
gold_price_clean.reset_index(inplace=True)

# %%
plt.style.use('seaborn-whitegrid')
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(gold_price['Name'], gold_price['US dollar.1'])
ax.set(title='Gold price through the years', xlabel='Years', ylabel='Price')
# Out:
# [Text(0.5, 1.0, 'Gold price through the years'),
#  Text(0.5, 0, 'Years'),
#  Text(0, 0.5, 'Price')]

# %%
gold_price.plot('Name', figsize=(10,50), subplots=True);
